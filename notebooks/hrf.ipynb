# %%
# %cd mmsegmentation
# Out:
# /home/featurize/work/mmsegmentation

# %%
# !wget -P ./dataset_zip/ https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/healthy.zip https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/glaucoma.zip https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/diabetic_retinopathy.zip https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/healthy_manualsegm.zip https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/glaucoma_manualsegm.zip https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/diabetic_retinopathy_manualsegm.zip

# %%
# !wget -P ./dataset_zip/ https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/diabetic_retinopathy.zip
# Out:
# --2022-02-25 09:32:36--  https://www5.cs.fau.de/fileadmin/research/datasets/fundus-images/diabetic_retinopathy.zip
# Connecting to 172.16.0.13:5848... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 29249219 (28M) [application/zip]
# Saving to: ‘./dataset_zip/diabetic_retinopathy.zip’
#
# diabetic_retinopath 100%[===================>]  27.89M  53.0KB/s    in 5m 44s
#
# 2022-02-25 09:38:22 (82.9 KB/s) - ‘./dataset_zip/diabetic_retinopathy.zip’ saved [29249219/29249219]

# %%
# !python ./tools/convert_datasets/hrf.py ./dataset_zip/healthy.zip ./dataset_zip/healthy_manualsegm.zip ./dataset_zip/glaucoma.zip ./dataset_zip/glaucoma_manualsegm.zip ./dataset_zip/diabetic_retinopathy.zip ./dataset_zip/diabetic_retinopathy_manualsegm.zip
# Out:
# Making directories...
# Generating images...
# Generating annotations...
# Done!

# %%
# !python ./tools/train.py ./configs/unet/deeplabv3_unet_s5-d16_256x256_40k_hrf.py
# Out:
# 2022-02-25 09:38:50,764 - mmseg - INFO - Multi-processing start method is `None`
# 2022-02-25 09:38:50,764 - mmseg - INFO - OpenCV num_threads is `<built-in function getNumThreads>
# 2022-02-25 09:38:50,823 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.10 (default, Jun  4 2021, 14:48:32) [GCC 7.5.0]
# CUDA available: True
# GPU 0: NVIDIA GeForce RTX 3080
# CUDA_HOME: /usr/local/cuda
# NVCC: Build cuda_11.2.r11.2/compiler.29618528_0
# GCC: gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0
# PyTorch: 1.10.0+cu113
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
# ...
