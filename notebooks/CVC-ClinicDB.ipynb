# %%
# %cd mmsegmentation
# Out:
# /home/featurize/work/mmsegmentation

# %%
# !python ./tools/convert_datasets/CVC-ClinicDB.py ./dataset_zip/CVC-ClinicDB.zip
# Out:
# Making directories...
# Extracting CVC-ClinicDB.zip...
# Generating training dataset...
# 1-mask.png
# 1.jpg
# 10-mask.png
# 10.jpg
# 100-mask.png
# 100.jpg
# 101-mask.png
# 101.jpg
# 102-mask.png
# 102.jpg
# 103-mask.png
# 103.jpg
# 104-mask.png
# 104.jpg
# 105-mask.png
# 105.jpg
# 106-mask.png
# 106.jpg
# 107-mask.png
# 107.jpg
# 108-mask.png
# 108.jpg
# 109-mask.png
# 109.jpg
# 11-mask.png
# 11.jpg
# 110-mask.png
# 110.jpg
# 111-mask.png
# 111.jpg
# 112-mask.png
# 112.jpg
# 113-mask.png
# 113.jpg
# 114-mask.png
# 114.jpg
# 115-mask.png
# 115.jpg
# 116-mask.png
# 116.jpg
# 117-mask.png
# 117.jpg
# 118-mask.png
# 118.jpg
# 119-mask.png
# 119.jpg
# 12-mask.png
# 12.jpg
# 120-mask.png
# 120.jpg
# 121-mask.png
# 121.jpg
# 122-mask.png
# 122.jpg
# 123-mask.png
# 123.jpg
# 124-mask.png
# 124.jpg
# 125-mask.png
# 125.jpg
# 126-mask.png
# 126.jpg
# 127-mask.png
# 127.jpg
# 128-mask.png
# 128.jpg
# 129-mask.png
# 129.jpg
# 13-mask.png
# 13.jpg
# 130-mask.png
# 130.jpg
# 131-mask.png
# ...

# %%
# !python ./tools/train.py ./configs/unet/pspnet_unet_s5-d16_128x128_40k_CVC-ClinicDB.py
# Out:
# 2022-03-16 16:25:28,137 - mmseg - INFO - Multi-processing start method is `None`
# 2022-03-16 16:25:28,137 - mmseg - INFO - OpenCV num_threads is `<built-in function getNumThreads>
# 2022-03-16 16:25:28,232 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.10 (default, Jun  4 2021, 14:48:32) [GCC 7.5.0]
# CUDA available: True
# GPU 0: NVIDIA GeForce RTX 3080
# CUDA_HOME: /usr/local/cuda
# NVCC: Build cuda_11.2.r11.2/compiler.29618528_0
# GCC: gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0
# PyTorch: 1.10.0+cu111
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
# ...
