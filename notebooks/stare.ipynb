# %%
# %cd mmsegmentation
# !wget -P ./dataset_zip/ http://cecas.clemson.edu/~ahoover/stare/probing/stare-images.tar http://cecas.clemson.edu/~ahoover/stare/probing/labels-ah.tar http://cecas.clemson.edu/~ahoover/stare/probing/labels-vk.tar
# Out:
# [Errno 2] No such file or directory: 'mmsegmentation'
# /home/featurize/mmsegmentation
# --2022-02-25 15:10:13--  http://cecas.clemson.edu/~ahoover/stare/probing/stare-images.tar
# Connecting to 172.16.0.13:5848... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 18674176 (18M) [application/x-tar]
# Saving to: ‘./dataset_zip/stare-images.tar.1’
#
# stare-images.tar.1  100%[===================>]  17.81M  5.26KB/s    in 47m 46s
#
# 2022-02-25 15:57:59 (6.36 KB/s) - ‘./dataset_zip/stare-images.tar.1’ saved [18674176/18674176]
#
# --2022-02-25 15:57:59--  http://cecas.clemson.edu/~ahoover/stare/probing/labels-ah.tar
# Reusing existing connection to 172.16.0.13:5848.
# Proxy request sent, awaiting response... 200 OK
# Length: 241664 (236K) [application/x-tar]
# Saving to: ‘./dataset_zip/labels-ah.tar’
#
# labels-ah.tar       100%[===================>] 236.00K  4.73KB/s    in 35s
#
# ...

# %%
# !python ./tools/convert_datasets/stare.py ./dataset_zip/stare-images.tar ./dataset_zip/labels-ah.tar ./dataset_zip/labels-vk.tar
# Out:
# Making directories...
# Extracting stare-images.tar...
# Removing the temporary files...
# Extracting labels-ah.tar...
# Removing the temporary files...
# Extracting labels-vk.tar...
# Removing the temporary files...
# Done!

# %%
# !python ./tools/train.py ./configs/unet/deeplabv3_unet_s5-d16_128x128_40k_stare.py
# Out:
# 2022-02-25 16:52:44,264 - mmseg - INFO - Multi-processing start method is `None`
# 2022-02-25 16:52:44,264 - mmseg - INFO - OpenCV num_threads is `<built-in function getNumThreads>
# 2022-02-25 16:52:44,315 - mmseg - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.10 (default, Jun  4 2021, 14:48:32) [GCC 7.5.0]
# CUDA available: True
# GPU 0: NVIDIA GeForce RTX 3080
# CUDA_HOME: /usr/local/cuda
# NVCC: Build cuda_11.2.r11.2/compiler.29618528_0
# GCC: gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0
# PyTorch: 1.10.0+cu113
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
# ...
